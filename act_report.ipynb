# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# **Insights**
#
# I generated insights on four insights and made one visualization.
# To start with, I read the cleaned master data set afresh and visualized it. Then I got my first insight that Atticus is the name of the dog with the highest rating. I got this by figuring out the highest rating in the rating numerator column by applying the max method to the series. After figuring out the maximum rating, I then quarried the data set to print out the details of the row with the highest numerator rating.
# Next, I got my second insight that the majority of the tweet did not state the dog stage they were rating. I figured this out by applying the value count method to the dog stage series. This gave a 1598 count of tweets that did not state the doge stage of the dog they were rating. Additionally, this code gave the insight that the most rated dog based on stage are dogs at the pupper stage.
# My last insight is that the dog with the highest retweets dog is at stage doggo. I got this by figuring out the highest retweet count. After figuring out the maximum retweet count, I then quarried the data set to print out the details of the row with the highest retweet count then I identified the dog stage.
#
# **Visualization**
#
# I created a bar graph of the dogs with the 20 highest ratings. I first figured out the dogs with the highest ratings. Then I grouped them by name and formed a new set of data called higher ratings. Then I plotted a bar graph using the data. The plotted bar graph is shown below.

# %% [markdown]
# ![download%20pic.png](attachment:download%20pic.png)
